# %%
k_cross_fold_times = \
[('Random', 109.77), 
('Random', 23.38), 
('Random', 53.82), 
('Random', 27.81), 
('Random', 49.71), 
('Random', 89.03), 
('Random', 45.00), 
('Random', 100.15), 
('Random', 23.41), 
('Random', 56.08), 
('Random', 28.64), 
('Random', 50.61), 
('Random', 96.66), 
('Random', 48.99), 
('Logistic', 18.05), 
('Logistic', 168.12), 
('Logistic', 4.99), 
('Logistic', 23.74), 
('Logistic', 20.57), 
('Logistic', 3.95), 
('K', 174.93), 
('K', 177.20), 
('K', 20.62), 
('K', 191.45), 
('K', 179.30), 
('K', 17.63), 
('Neural', 237.35), 
('Neural', 34.18), 
('Neural', 254.33), 
('Neural', 69.28), 
('Neural', 20.46), 
('Neural', 266.93), 
('Neural', 17.90), 
('Neural', 154.89), 
('Random', 99.31), 
('Random', 22.39), 
('Random', 56.11), 
('Random', 28.30), 
('Random', 42.37), 
('Random', 69.69), 
('Random', 35.12), 
('Random', 81.20), 
('Random', 17.77), 
('Random', 44.28), 
('Random', 22.65), 
('Random', 38.27), 
('Random', 76.29), 
('Random', 38.42), 
('Logistic', 10.22), 
('Logistic', 207.45), 
('Logistic', 9.25), 
('Logistic', 45.37), 
('Logistic', 32.57), 
('Logistic', 3.78), 
('K', 185.12), 
('K', 159.65), 
('K', 16.55), 
('K', 141.02), 
('K', 157.65), 
('K', 16.73), 
('Neural', 22.16), 
('Neural', 56.94), 
('Neural', 21.98), 
('Neural', 160.80), 
('Neural', 16.89), 
('Neural', 213.19), 
('Neural', 17.27), 
('Neural', 128.15), 
('Random', 73.80), 
('Random', 17.34), 
('Random', 43.71), 
('Random', 21.68), 
('Random', 37.10), 
('Random', 70.65), 
('Random', 35.54), 
('Random', 77.58), 
('Random', 18.07), 
('Random', 44.37), 
('Random', 22.02), 
('Random', 38.63), 
('Random', 70.97), 
('Random', 35.66), 
('Logistic', 10.41), 
('Logistic', 128.20), 
('Logistic', 1.66), 
('Logistic', 16.14), 
('Logistic', 17.89), 
('Logistic', 3.10), 
('K', 143.46), 
('K', 149.91), 
('K', 16.94), 
('K', 140.38), 
('K', 149.59), 
('K', 16.79), 
('Neural', 24.61), 
('Neural', 66.33), 
('Neural', 24.54), 
('Neural', 56.62), 
('Neural', 16.79), 
('Neural', 226.71), 
('Neural', 17.10), 
('Neural', 125.54), 
('Random', 76.61), 
('Random', 17.83), 
('Random', 44.41), 
('Random', 22.32), 
('Random', 36.72), 
('Random', 70.87), 
('Random', 35.31), 
('Random', 77.35), 
('Random', 18.21), 
('Random', 45.11), 
('Random', 22.80), 
('Random', 38.63), 
('Random', 71.62), 
('Random', 36.62), 
('Logistic', 9.58), 
('Logistic', 118.72), 
('Logistic', 1.57), 
('Logistic', 15.92), 
('Logistic', 17.42), 
('Logistic', 3.05), 
('K', 144.49), 
('K', 151.09), 
('K', 16.63), 
('K', 143.91), 
('K', 196.65), 
('K', 17.26), 
('Neural', 244.79), 
('Neural', 34.41), 
('Neural', 247.17), 
('Neural', 209.70), 
('Neural', 17.21), 
('Neural', 217.64), 
('Neural', 17.22), 
('Neural', 123.36), 
('Random', 73.95), 
('Random', 17.47), 
('Random', 44.26), 
('Random', 22.24), 
('Random', 36.86), 
('Random', 69.48), 
('Random', 35.31), 
('Random', 76.87), 
('Random', 17.88), 
('Random', 44.08), 
('Random', 22.90), 
('Random', 38.47), 
('Random', 71.25), 
('Random', 35.49), 
('Logistic', 9.81), 
('Logistic', 111.83), 
('Logistic', 1.59), 
('Logistic', 16.00), 
('Logistic', 19.68), 
('Logistic', 3.28), 
('K', 148.98), 
('K', 150.38), 
('K', 16.78), 
('K', 143.44), 
('K', 149.68), 
('K', 16.97), 
('Neural', 24.13), 
('Neural', 64.89), 
('Neural', 24.49), 
('Neural', 148.56), 
('Neural', 17.01), 
('Neural', 231.09), 
('Neural', 16.82), 
('Neural', 133.87), 
('Random', 73.65), 
('Random', 17.28), 
('Random', 43.81), 
('Random', 22.09), 
('Random', 37.62), 
('Random', 70.61), 
('Random', 35.22), 
('Random', 77.01), 
('Random', 17.72), 
('Random', 44.28), 
('Random', 22.46), 
('Random', 38.36), 
('Random', 76.09), 
('Random', 37.92), 
('Logistic', 11.71), 
('Logistic', 126.48), 
('Logistic', 1.56), 
('Logistic', 15.94), 
('Logistic', 17.11), 
('Logistic', 3.16), 
('K', 150.95), 
('K', 150.20), 
('K', 16.50), 
('K', 140.06), 
('K', 150.77), 
('K', 16.86), 
('Neural', 248.78), 
('Neural', 67.79), 
('Neural', 248.41), 
('Neural', 92.01), 
('Neural', 16.89), 
('Neural', 224.36), 
('Neural', 16.79), 
('Neural', 131.82), 
('Random', 74.41), 
('Random', 17.67), 
('Random', 44.08), 
('Random', 21.88), 
('Random', 38.04), 
('Random', 70.17), 
('Random', 35.20), 
('Random', 76.76), 
('Random', 17.72), 
('Random', 44.15), 
('Random', 22.14), 
('Random', 38.40), 
('Random', 70.82), 
('Random', 36.34), 
('Logistic', 9.14), 
('Logistic', 128.52), 
('Logistic', 1.57), 
('Logistic', 15.78), 
('Logistic', 17.27), 
('Logistic', 3.11), 
('K', 140.31), 
('K', 153.96), 
('K', 16.91), 
('K', 141.56), 
('K', 151.21), 
('K', 17.25), 
('Neural', 22.30), 
('Neural', 41.66), 
('Neural', 21.99), 
('Neural', 143.57), 
('Neural', 16.94), 
('Neural', 216.32), 
('Neural', 17.25), 
('Neural', 137.56), 
('Random', 74.15), 
('Random', 17.65), 
('Random', 44.43), 
('Random', 22.65), 
('Random', 38.66), 
('Random', 69.76), 
('Random', 35.05), 
('Random', 77.16), 
('Random', 17.86), 
('Random', 44.50), 
('Random', 22.29), 
('Random', 38.54), 
('Random', 71.14), 
('Random', 36.12), 
('Logistic', 10.11), 
('Logistic', 124.73), 
('Logistic', 1.56), 
('Logistic', 15.99), 
('Logistic', 17.18), 
('Logistic', 3.28), 
('K', 139.24), 
('K', 159.82), 
('K', 17.14), 
('K', 139.07), 
('K', 148.34), 
('K', 16.95), 
('Neural', 233.82), 
('Neural', 37.28), 
('Neural', 233.58), 
('Neural', 127.08), 
('Neural', 17.24), 
('Neural', 218.52), 
('Neural', 16.67), 
('Neural', 124.44), 
('Random', 73.79), 
('Random', 17.32), 
('Random', 42.80), 
('Random', 22.04), 
('Random', 36.75), 
('Random', 69.10), 
('Random', 34.83), 
('Random', 76.81), 
('Random', 17.84), 
('Random', 43.96), 
('Random', 22.31), 
('Random', 38.49), 
('Random', 70.77), 
('Random', 37.30), 
('Logistic', 10.48), 
('Logistic', 105.49), 
('Logistic', 1.62), 
('Logistic', 16.24), 
('Logistic', 17.43), 
('Logistic', 3.22), 
('K', 139.87), 
('K', 163.64), 
('K', 18.48), 
('K', 150.42), 
('K', 149.03), 
('K', 19.51), 
('Neural', 269.03), 
('Neural', 67.03), 
('Neural', 271.12), 
('Neural', 47.96), 
('Neural', 16.71), 
('Neural', 207.60), 
('Neural', 16.75), 
('Neural', 130.94), 
('Random', 73.25), 
('Random', 16.94), 
('Random', 43.36), 
('Random', 21.44), 
('Random', 36.74), 
('Random', 68.64), 
('Random', 35.05), 
('Random', 76.39), 
('Random', 17.76), 
('Random', 44.38), 
('Random', 21.81), 
('Random', 38.10), 
('Random', 72.71), 
('Random', 35.65), 
('Logistic', 9.35), 
('Logistic', 134.58), 
('Logistic', 1.61), 
('Logistic', 15.87), 
('Logistic', 17.50), 
('Logistic', 3.23), 
('K', 139.72), 
('K', 149.57), 
('K', 16.46), 
('K', 140.85), 
('K', 148.37), 
('K', 16.35), 
('Neural', 55.04), 
('Neural', 37.12), 
('Neural', 55.53), 
('Neural', 109.06), 
('Neural', 16.57), 
('Neural', 221.29), 
('Neural', 16.72), 
('Neural', 122.75)]

# %%
from statistics import mean, stdev
unique_vals = list(set([i[0] for i in k_cross_fold_times]))
result = {}
for val in unique_vals:
    values = [i[1] for i in k_cross_fold_times if i[0]==val]
    result[val] = (mean(values), stdev(values))
result
# Out:
# {'K': (107.8425, 65.70133723131555),
#  'Random': (45.296142857142854, 22.45616691462349),
#  'Logistic': (31.912166666666668, 48.83211308255403),
#  'Neural': (104.469875, 89.31843157474005)}
